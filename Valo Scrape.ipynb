# %%
import bs4
import requests

# %%
res = requests.get('https://liquipedia.net/valorant/VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics')

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs Send_pizza_to_FO-nTTaX All_glory_to_Liquipedia" lang="en" dir="ltr" prefix="og: http://ogp.me/ns#">\n<head>\n<meta charset="UTF-8"/>\n<title>VALORANT Champions Tour 2021: Stage 2 Masters - Reykjavík: Statistics - Liquipedia VALORANT Wiki</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics","wgTitle":"VALORANT Champions Tour/2021/Stage 2/Masters/Statistics","wgCurRevisionId":260698,"wgRevisionId":260698,"wgArticleId":19185,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages with hard coded colors"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics","wgRelevantArticleId":19185,"wgRequestId":"243cae8281c579a9a7df72a8","wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"accuracy":{"levels":3,"quality":2,"pristine":4},"depth":{"levels":3,"quality":1,"pristine":4},"style":{"levels":3,"quality":1,"pristine":4}}},"wgStableRevisionId":260698,"wgPageFormsTargetName":null,"wgPageFormsAutocompleteValues":[],"wgPageFormsAutocompleteOnAllChars":false,"wgPageFormsFieldProperties":[],"wgPageFormsCargoFields":[],"wgPageFormsDependentFields":[],"wgPageFormsCalendarValues":[],"wgPageFormsCalendarParams":[],"wgPageFormsCalendarHTML":null,"wgPageFormsGridValues":[],"wgPageFormsGridParams":[],"wgPageFormsContLangYes":null,"wgPageFormsContLangNo":null,"wgPageFormsContLangMonths":[],"wgPageFormsHeightForMinimizingInstances":800,"wgPageFormsShowOnSelect":[],"wgPageFormsScriptPath":"/valorant/extensions/PageForms","edgValues":null,"wgPageFormsEDSettings":null,"wgAmericanDates":false,"LengthOfUrl":"100","UpdateNotificationServerDomain":"https://liquipedia.net/","UpdateNotificationServerSubPath":"/notifications/","wgWikiEditorEnabledModules":[],"wgValorantImagePath":"/valorant/extensions/ValorantDB/resources/images/","liquiflowCacheVersion":"1","srfFilteredConfig":null});mw.loader.state({"site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","site":"ready","user.options":"ready","user.tokens":"loading","ext.brackets.Bracket.styles":"ready","ext.bugtracker":"ready","ext.liquipediaads":"ready","ext.networknotice.Notice":"ready","ext.TeamLiquidIntegration.liquipedia-custom-icons":"ready","fontawesome-pro":"ready","ext.wikimenu.wikicolors":"ready","ext.srf.styles":"ready","ext.smw.style":"ready","ext.smw.tooltip.styles":"ready","ext.flaggedRevs.basic":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.bruinen.theme.valorant":"ready"});mw.loader.implement("user.tokens@1lrhs6l",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});mw.loader.load(["ext.Charts.scripts","ext.smw.style","ext.smw.tooltips","ext.scribunto.logs","smw.entityexaminer","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","mediawiki.searchSuggest","ext.AchievementsNotification.scripts","ext.brackets.Bracket.scripts","ext.ShortUrl.scripts","ext.tre ...

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs Send_pizza_to_FO-nTTaX All_glory_to_Liquipedia" dir="ltr" lang="en" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <title>VALORANT Champions Tour 2021: Stage 2 Masters - Reykjavík: Statistics - Liquipedia VALORANT Wiki</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics","wgTitle":"VALORANT Champions Tour/2021/Stage 2/Masters/Statistics","wgCurRevisionId":260698,"wgRevisionId":260698,"wgArticleId":19185,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages with hard coded colors"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics","wgRelevantArticleId":19185,"wgRequestId":"243cae8281c579a9a7df72a8","wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"accuracy":{"levels":3,"quality":2,"pristine":4},"depth":{"levels":3,"quality":1,"pristine":4},"style":{"levels":3,"quality":1,"pristine":4}}},"wgStableRevisionId":260698,"wgPageFormsTargetName":null,"wgPageFormsAutocompleteValues":[],"wgPageFormsAutocompleteOnAllChars":false,"wgPageFormsFieldProperties":[],"wgPageFormsCargoFields":[],"wgPageFormsDependentFields":[],"wgPageFormsCalendarValues":[],"wgPageFormsCalendarParams":[],"wgPageFormsCalendarHTML":null,"wgPageFormsGridValues":[],"wgPageFormsGridParams":[],"wgPageFormsContLangYes":null,"wgPageFormsContLangNo":null,"wgPageFormsContLangMonths":[],"wgPageFormsHeightForMinimizingInstances":800,"wgPageFormsShowOnSelect":[],"wgPageFormsScriptPath":"/valorant/extensions/PageForms","edgValues":null,"wgPageFormsEDSettings":null,"wgAmericanDates":false,"LengthOfUrl":"100","UpdateNotificationServerDomain":"https://liquipedia.net/","UpdateNotificationServerSubPath":"/notifications/","wgWikiEditorEnabledModules":[],"wgValorantImagePath":"/valorant/extensions/ValorantDB/resources/images/","liquiflowCacheVersion":"1","srfFilteredConfig":null});mw.loader.state({"site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","site":"ready","user.options":"ready","user.tokens":"loading","ext.brackets.Bracket.styles":"ready","ext.bugtracker":"ready","ext.liquipediaads":"ready","ext.networknotice.Notice":"ready","ext.TeamLiquidIntegration.liquipedia-custom-icons":"ready","fontawesome-pro":"ready","ext.wikimenu.wikicolors":"ready","ext.srf.styles":"ready","ext.smw.style":"ready","ext.smw.tooltip.styles":"ready","ext.flaggedRevs.basic":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.bruinen.theme.valorant":"ready"});mw.loader.implement("user.tokens@1lrhs6l",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });mw.loader.load(["ext.Charts.scripts","ext.smw.style","ext.smw.tooltips","ext.scribunto.logs","smw.entityexaminer","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","mediawiki.searchSuggest","ext.AchievementsNotification.scripts","ext.brackets.Bracket.scripts","ext.ShortUrl.scripts","ext.trendingmenu","ext.Notification.scripts","ext.wikimenu.menu","ext.flaggedRevs.advanced","skins.bruinen.scripts"]);});</script>
# <link href="/valorant/load.php?debug=false&amp;lang=en&amp;modules=ext.TeamLiquidIntegration.liquipedia-custom-icons%7Cext.brackets.Bracket.styles%7Cext.bugtracker%2Cliquipediaads%7Cext.flaggedRevs.basic%7Cext.networknotice.Notice%7Cext.wikimenu.wikicolors%7Cfontawesome-pro%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.bruinen.theme.valorant&amp;only=styles&amp;skin=bruinen" rel="stylesheet"/>
# <link href="/valorant/load.php?debug=false&amp;lang=en&amp;modules=ext.smw.style%7Cext.smw.tooltip.styles&amp;only=styles&amp;skin=bruinen" rel="stylesheet"/>
# <link href="/valorant/load.php?debug=false&amp;lang=en&amp;modules=ext.srf.styles&amp;only=styles&amp;skin=bruinen" rel="stylesheet"/>
# <script async="" src="/valorant/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=bruinen"></script>
# <link href="/commons/load.php?debug=false&amp;articles=Variables.css%7CAmbox.css%7CBracket.css%7CBrackets.css%7CColours.css%7CCrosstable.css%7CDivTable.css%7CFilterButtons.css%7CGrid.css%7CIcons.css%7CInfobox.css%7CMainpage.css%7CMiscellaneous.css%7CNavFrame.css%7CNavbox.css%7CPanels.css%7CPrizepooltable.css%7CQuote.css%7CSelectall.css%7CStatisticstable.css%7CSwisstable.css%7CTables.css%7CTabs.css%7CTeamTemplates.css%7CTeamcard.css%7CTechtree.css&amp;only=styles&amp;mode=articles&amp;cacheversion=45&amp;*" rel="stylesheet"/><link href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,700;1,300;1,400;1,700&amp;family=Droid+Sans+Mono&amp;family=Source+Code+Pro:wght@400;700&amp;display=swap" rel="stylesheet"/><link href="https://fonts.googleapis.com/css2?family=Roboto:wght@500&amp;display=swap&amp;text=adehilpqu" rel="stylesheet"/><style>#mw-indicator-mw-helplink {display:none;}</style>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/valorant/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=bruinen" rel="stylesheet"/>
# <meta content="MediaWiki 1.31.14" name="generator"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="#e6e6e6" name="theme-color"/>
# <link href="/valorant/index.php?title=Special:ExportRDF/VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics&amp;xmlmime=rdf" rel="alternate" title="VALORANT Champions Tour/2021/Stage 2/Masters/Statistics" type="application/rdf+xml"/>
# <link href="/valorant/opensearch_desc.php" rel="search" title="Liquipedia VALORANT Wiki (en)" type="application/opensearchdescription+xml"/>
# <link href="https://liquipedia.net/valorant/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="/valorant/Liquipedia:Copyrights" rel="license"/>
# <!--
# 	************************************************
# 	*  _ _             _                _ _        *
# 	* | (_) __ _ _   _(_)_ __   ___  __| (_) __ _  *
# 	* | | |/ _` | | | | | '_ \ / _ \/ _` | |/ _` | *
# 	* | | | (_| | |_| | | |_) |  __/ (_| | | (_| | *
# 	* |_|_|\__, |\__,_|_| .__/ \___|\__,_|_|\__,_| *
# 	*         |_|       |_|                        *
# 	************************************************
# -->
# <link href="/valorant/extensions/SearchEngineOptimization/resources/images/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/favicon-128x128.png" rel="icon" sizes="128x128" type="image/png"/><link href="/valorant/extensions/SearchEngineOptimization/resources/images/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/><link content="Liquipedia VALORANT Wiki" href="/valorant/extensions/SearchEngineOptimization/resources/images/favicon-196x196.png" name="application-name" type="image/png"/><link content="#ffffff" name="msapplication-TileColor"/><link content="/valorant/extensions/SearchEngineOptimization/resources/images/mstile-144x144.png" name="msapplication-TileImage"/><link content="/valorant/extensions/SearchEngineOptimization/resources/images/mstile-70x70.png" name="msapplication-square70x70logo"/><link content="/valorant/extensions/SearchEngineOptimization/resources/images/mstile-150x150.png" name="msapplication-square150x150logo"/><link content="/valorant/extensions/SearchEngineOptimization/resources/images/mstile-310x150.png" name="msapplication-wide310x150logo"/><link content="/valorant/extensions/SearchEngineOptimization/resources/images/mstile-310x310.png" name="msapplication-square310x310logo"/>
# <link href="https://liquipedia.net/valorant/VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics" rel="canonical"/>
# <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
# 	var googletag = googletag || {};
# 	googletag.cmd = googletag.cmd || [];
# 	googletag.cmd.push( function () {
# 		googletag.pubads().setTargeting( 'url', location.pathname );
# 	} );
# </script>
# <script type="text/javascript">
#   window["nitroAds"] = window["nitroAds"] || {
#     createAd: function() {
#       window.nitroAds.queue.push(["createAd", arguments]);
#     },
#     queue: []
#   };
# </script>
# <script async="" src="https://s.nitropay.com/ads-90.js"></script>
# <!--[if lt IE 9]><script src="/valorant/load.php?debug=false&amp;lang=en&amp;modules=html5shiv&amp;only=scripts&amp;skin=Bruinen&amp;sync=1"></script><![endif]-->
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-VALORANT_Champions_Tour_2021_Stage_2_Masters_Statistics rootpage-VALORANT_Champions_Tour skin-bruinen action-view wiki-valorant logged-out" id="top"><nav class="main-nav navbar navbar-expand-md navbar-dark bg-theme noprint" id="main-nav"><div class="container container-custom"><a class="navbar-brand" href="/valorant/Main_Page" title="Visit the main page"><img alt="Logo" class="brand-logo" id="brand-logo" src="/commons/extensions/TeamLiquidIntegration/resources/pagelogo/liquipedia_icon_menu.png"/></a
# <ul class="nav">
# <li class="toclevel-1 tocsection-1"><a class="nav-link" data-target="#Player_Statistics" href="#Player_Statistics"><span class="tocnumber">1</span> <span class="toctext">Player Statistics</span></a></li>
# <li class="toclevel-1 tocsection-2"><a class="nav-link" data-target="#Map_Statistics" href="#Map_Statistics"><span class="tocnumber">2</span> <span class="toctext">Map Statistics</span></a>
# <ul class="nav">
# <li class="toclevel-2"><a class="nav-link" data-target="#Maps_Picked" href="#Maps_Picked"><span class="tocnumber">2.1</span> <span class="toctext">Maps Picked</span></a></li>
# <li class="toclevel-2"><a class="nav-link" data-target="#Side_Statistics" href="#Side_Statistics"><span class="tocnumber">2.2</span> <span class="toctext">Side Statistics</span></a></li>
# <li class="toclevel-2"><a class="nav-link" data-target="#Maps_Banned" href="#Maps_Banned"><span class="tocnumber">2.3</span> <span class="toctext">Maps Banned</span></a></li>
# <li class="toclevel-2"><a class="nav-link" data-target="#Maps_Picked_2" href="#Maps_Picked_2"><span class="tocnumber">2.4</span> <span class="toctext">Maps Picked</span></a></li>
# <li class="toclevel-2"><a class="nav-link" data-target="#Maps_Banned_2" href="#Maps_Banned_2"><span class="tocnumber">2.5</span> <span class="toctext">Maps Banned</span></a></li>
# </ul>
# </li>
# </ul>
# <div class="navigation-not-searchable" id="sidebar-ad"><div id="anyclip_liquipedia_valorant"></div></div></div></div><div class="container-layout main-content-column main-content" id="main-content-column"><div class="mw-body" id="main-content"><div id="siteNotice"><div class="networknotice networknotice-default bgc-light bdc-dark" data-id="19" id="networknotice-19">Follow us on Twitter <a class="external text" href="https://twitter.com/LiquipediaVAL" rel="noopener" target="_blank">@LiquipediaVAL</a> if you'd like to be kept up to date on all things VALORANT!</div></div><div class="navigation-not-searchable" id="top-ad"><div id="valorant_970x90_ATF"></div></div><h1 class="firstHeading" id="firstHeading"><span dir="auto">VALORANT Champions Tour 2021: Stage 2 Masters - Reykjavík: Statistics</span></h1><div class="mw-body-content" id="bodyContent"><div id="siteSub">From Liquipedia VALORANT Wiki</div><div class="content-sub" id="contentSub"><span class="subpages"><nav aria-label="breadcrumb"><ol class="breadcrumb"><li class="breadcrumb-item"><a href="/valorant/VALORANT_Champions_Tour/2021" title="VALORANT Champions Tour/2021">VALORANT Champions Tour/2021</a></li><li class="breadcrumb-item"><a href="/valorant/VALORANT_Champions_Tour/2021/Stage_2/Masters" title="VALORANT Champions Tour/2021/Stage 2/Masters">Stage 2/Masters</a></li><li class="breadcrumb-item"><a href="/valorant/VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics" title="VALORANT Champions Tour/2021/Stage 2/Masters/Statistics">Statistics</a></li></ol></nav></span></div><div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><div
-align:center">1<i>×</i></td><td style="text-align:center">1<i>×</i></td><td style="text-align:center;color:rgb(154, 154, 154)">0<i>×</i></td><td style="text-align:center">2<i>×</i></td><td style="text-align:center">2<i>×</i></td><td style="text-align:center">2<i>×</i></td><td style="text-align:center;color:rgb(154, 154, 154)">0<i>×</i></td></tr><tr><th style="text-align:left;background-color:rgb(249, 249, 249)"><b><a href="/valorant/Split" title="Split">Split</a></b></th><th style="text-align:center">12<i>×</i></th><td style="text-align:center">3<i>×</i></td><td style="text-align:center">2<i>×</i></td><td style="text-align:center">3<i>×</i></td><td style="text-align:center">1<i>×</i></td><td style="text-align:center">2<i>×</i></td><td style="text-align:center">1<i>×</i></td><td style="text-align:center;color:rgb(154, 154, 154)">0<i>×</i></td></tr></tbody></table></div>
# </div></div>
# <div><div class="template-box" style="padding-right:2em;">
# <h3><span class="mw-headline" id="Maps_Picked_2">Maps Picked</span></h3>
# <div id="bar-area-0" style="width:700px;height:500px;"></div>
# <p> <template class="navigation-not-searchable charts-barchart">{"colors":["#4e79a5","#f1903b","#e0585b","#77b7b2","#edca58","#7132a8","#65c654","#FF66FF","#FF6699","#FF3300","#CCFFFF","#CCFF66","#CCCCCC","#CCCC33","#CC33FF","#CC3333","#9999FF","#66FFFF","#66FF00","#666699","#663300","#3366FF","#33CC00","#336633","#0066FF","#009999","#000099","#03a1db","#aed79a","#8e6e5b","#637d8d","#692627","#ecf074","#1dd0a3","#5f7942","#7ba83d","#000000"],"data":[{"name":"Ascent","Day 1":3,"Day 2":3,"Day 3":2,"Day 4":3,"Day 5":2,"Day 6":2,"Day 7":1},{"name":"Bind","Day 1":1,"Day 2":0,"Day 3":2,"Day 4":1,"Day 5":2,"Day 6":2,"Day 7":1},{"name":"Haven","Day 1":3,"Day 2":3,"Day 3":2,"Day 4":2,"Day 5":3,"Day 6":1,"Day 7":1},{"name":"Icebox","Day 1":2,"Day 2":2,"Day 3":3,"Day 4":1,"Day 5":1,"Day 6":0,"Day 7":1},{"name":"Split","Day 1":0,"Day 2":1,"Day 3":0,"Day 4":2,"Day 5":1,"Day 6":1,"Day 7":1}],"keys":["Day 1","Day 2","Day 3","Day 4","Day 5","Day 6","Day 7"],"maxY":16,"minY":0,"stacked":true,"labels":{"x":"Map","y":"Times Picked"},"size":{"height":500,"width":700},"div":"bar-area-0"}</template>
# </p>
# </div>
# <div class="template-box" style="padding-right:2em;">
# <h3><span class="mw-headline" id="Maps_Banned_2">Maps Banned</span></h3>
# <div id="bar-area-1" style="width:700px;height:500px;"></div>
# <p> <template class="navigation-not-searchable charts-barchart">{"colors":["#4e79a5","#f1903b","#e0585b","#77b7b2","#edca58","#7132a8","#65c654","#FF66FF","#FF6699","#FF3300","#CCFFFF","#CCFF66","#CCCCCC","#CCCC33","#CC33FF","#CC3333","#9999FF","#66FFFF","#66FF00","#666699","#663300","#3366FF","#33CC00","#336633","#0066FF","#009999","#000099","#03a1db","#aed79a","#8e6e5b","#637d8d","#692627","#ecf074","#1dd0a3","#5f7942","#7ba83d","#000000"],"data":[{"name":"Ascent","Day 1":0,"Day 2":0,"Day 3":1,"Day 4":0,"Day 5":1,"Day 6":0,"Day 7":0},{"name":"Bind","Day 1":2,"Day 2":3,"Day 3":1,"Day 4":2,"Day 5":1,"Day 6":0,"Day 7":0},{"name":"Haven","Day 1":0,"Day 2":0,"Day 3":1,"Day 4":1,"Day 5":0,"Day 6":1,"Day 7":0},{"name":"Icebox","Day 1":1,"Day 2":1,"Day 3":0,"Day 4":2,"Day 5":2,"Day 6":2,"Day 7":0},{"name":"Split","Day 1":3,"Day 2":2,"Day 3":3,"Day 4":1,"Day 5":2,"Day 6":1,"Day 7":0}],"keys":["Day 1","Day 2","Day 3","Day 4","Day 5","Day 6","Day 7"],"maxY":12,"minY":0,"stacked":true,"labels":{"x":"Map","y":"Times Banned"},"size":{"height":500,"width":700},"div":"bar-area-1"}</template>
# </p>
# </div></div>
# <p><br/>
# </p>
# <div class="content-ad navigation-not-searchable"><div id="valorant_970x250_BTF"></div></div>
# <!--
# NewPP limit report
# Cached time: 20210601010947
# Cache expiry: 3600
# Dynamic content: true
# [SMW] In‐text annotation parser time: 0.001 seconds
# CPU time usage: 0.648 seconds
# Real time usage: 0.820 seconds
# Preprocessor visited node count: 4117/1500000
# Preprocessor generated node count: 4823/1250000
# Post‐expand include size: 134372/3170304 bytes
# Template argument size: 105/3170304 bytes
# Highest expansion depth: 11/40
# Expensive parser function count: 0/100
# Unstrip recursion depth: 0/20
# Unstrip post‐expand size: 2190/5000000 bytes
# Lua time usage: 0.335/3.000 seconds
# Lua memory usage: 2.18 MB/50 MB
# Memory usage: 11 MB
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  431.697      1 -total
#  87.65%  378.394      1 Template:Recent_player_stats
#   8.61%   37.190      1 Template:TournamentStats
#   3.46%   14.937      1 Template:Tabs_static
#   1.24%    5.368      7 Template:Box
#   0.76%    3.271     12 Template:AgentBracket/sova_0.50
#   0.41%    1.756     12 Template:AgentBracket/jett_0.50
#   0.34%    1.477     10 Template:AgentBracket/sage_0.50
#   0.34%    1.454     10 Template:AgentBracket/raze_0.50
#   0.33%    1.438     10 Template:AgentBracket/viper_0.50
# -->
# </div>
# <!-- Saved in parser cache with key liquipedia-wikivalorant_:stable-pcache:idhash:19185-0!canonical and timestamp 20210601010947 and revision id 260698
#  -->
# </div><div class="printfooter">Retrieved from "<a dir="ltr" href="https://liquipedia.net/valorant/index.php?title=VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics&amp;oldid=260698">https://liquipedia.net/valorant/index.php?title=VALORANT_Champions_Tour/2021/Stage_2/Masters/Statistics&amp;oldid=260698</a>"</div><div class="catlinks catlinks-allhidden" data-mw="interface" id="catlinks"><div class="mw-hidden-catlinks mw-hidden-cats-hidden" id="mw-hidden-catlinks">Hidden category: <ul><li><a href="/valorant/Category:Pages_with_hard_coded_colors" title="Category:Pages with hard coded colors">Pages with hard coded colors</a></li></ul></div></div><div class="visualClear"></div></div></div></div></div><div class="footer" id="footer"><div class="container container-custom"><div class="row footer-links"><div class="col-md d-none d-md-block"><a class="footer-logo-big" href="/"></a></div><div class="col-
"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":2190,"limit":5000000},"timingprofile":["100.00%  431.697      1 -total"," 87.65%  378.394      1 Template:Recent_player_stats","  8.61%   37.190      1 Template:TournamentStats","  3.46%   14.937      1 Template:Tabs_static","  1.24%    5.368      7 Template:Box","  0.76%    3.271     12 Template:AgentBracket/sova_0.50","  0.41%    1.756     12 Template:AgentBracket/jett_0.50","  0.34%    1.477     10 Template:AgentBracket/sage_0.50","  0.34%    1.454     10 Template:AgentBracket/raze_0.50","  0.33%    1.438     10 Template:AgentBracket/viper_0.50"]},"scribunto":{"limitreport-timeusage":{"value":"0.335","limit":"3.000"},"limitreport-memusage":{"value":2282046,"limit":52428800},"limitreport-logs":"41\n \t1\tEffys\n \t1\tPenny\n \t1\tPeri\n \t1\tNeth\n \t1\tDapr\n \t1\tSScary\n \t1\tFoxz\n \t1\tSoulcas\n \t1\tGaabxx\n \t1\tProzin\n \t1\tZepher\n \t1\tAllow\n \t1\tZombs\n \t1\tVanity\n \t1\tSutecas\n \t1\tDelz1k\n \t1\tSolo\n \t1\tJammyz\n \t1\tSushiboys\n \t1\tBnj\n \t1\tFrz\n \t1\tRion\n \t1\tGtnziN\n \t1\tLight\n \t1\tFra\n"},"liquipedia":{"memory-usage":"11 MB"},"cachereport":{"timestamp":"20210601010947","ttl":3600,"transientcontent":true}}});});</script><script type="text/javascript">
# if(document.getElementById("valorant_336x280_BTF") !== null) {
# window["nitroAds"].createAd("valorant_336x280_BTF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["300","250"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-right"
#   },
#   "mediaQuery": "(min-width: 320px)"
# });
# }
# </script><script type="text/javascript">
# if(document.getElementById("anyclip_liquipedia_valorant") !== null) {
# window["nitroAds"].createAd("anyclip_liquipedia_valorant", {
#   "format": "video-ac",
#   "widgetname": "0011r00002Mc2QW_1843",
#   "mediaQuery": "(min-width: 1305px)"
# });
# }
# </script><script type="text/javascript">
# if(document.getElementById("valorant_300x250_SATF") !== null) {
# window["nitroAds"].createAd("valorant_300x250_SATF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": true,
#   "sizes": [
#     ["300","250"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-right"
#   },
#   "mediaQuery": "(min-width: 1305px)"
# });
# }
# </script><script type="text/javascript">
# if(document.getElementById("valorant_300x1050_SATF") !== null) {
# window["nitroAds"].createAd("valorant_300x1050_SATF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": false,
#   "refreshVisibleOnly": true,
#   "sizes": [
#     ["300","250"],
#     ["160","600"],
#     ["300","600"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-right"
#   },
#   "mediaQuery": "(min-width: 1305px)"
# });}
# </script><script type="text/javascript">
# window["nitroAds"].createAd("valorant_970x90_ATF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["320","50"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-center"
#   },
#   "mediaQuery": "(min-width: 320px) and (max-width: 747px)"
# });
# </script>
# <script type="text/javascript">
# window["nitroAds"].createAd("valorant_970x90_ATF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["728", "90"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-center"
#   },
#   "mediaQuery": "(min-width: 748px) and (max-width: 989px)"
# });
# </script>
# <script type="text/javascript">
# window["nitroAds"].createAd("valorant_970x90_ATF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["970","90"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-center"
#   },
#   "mediaQuery": "(min-width: 990px)"
# });
# </script><script type="text/javascript">
# if(document.getElementById("valorant_728x90_BTF") !== null) {
# window["nitroAds"].createAd("valorant_728x90_BTF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["320","50"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-center"
#   },
#   "mediaQuery": "(min-width: 320px) and (max-width: 747px)"
# });
# }
# </script>
# <script type="text/javascript">
# if(document.getElementById("valorant_728x90_BTF") !== null) {
# window["nitroAds"].createAd("valorant_728x90_BTF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["728", "90"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-center"
#   },
#   "mediaQuery": "(min-width: 748px)"
# });
# }
# </script><script type="text/javascript">
# if(document.getElementById("valorant_970x250_BTF") !== null) {
# window["nitroAds"].createAd("valorant_970x250_BTF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["320","50"],
#     ["300","250"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-center"
#   },
#   "mediaQuery": "(min-width: 320px) and (max-width: 747px)"
# });
# }
# </script>
# <script type="text/javascript">
# if(document.getElementById("valorant_970x250_BTF") !== null) {
# window["nitroAds"].createAd("valorant_970x250_BTF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["728", "90"],
#     ["300","250"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-center"
#   },
#   "mediaQuery": "(min-width: 748px) and (max-width: 989px)"
# });
# }
# </script><script type="text/javascript">
# if(document.getElementById("valorant_970x250_BTF") !== null) {
# window["nitroAds"].createAd("valorant_970x250_BTF", {
#   "refreshLimit": 10,
#   "refreshTime": 30,
#   "renderVisibleOnly": true,
#   "refreshVisibleOnly": true,
#   "visibleMargin": 0,
#   "sizes": [
#     ["728", "90"],
#     ["300","250"],
#     ["970","90"],
#     ["970","250"]
#   ],
#   "report": {
#     "enabled": true,
#     "wording": "Report Ad",
#     "position": "bottom-center"
#   },
#   "mediaQuery": "(min-width: 990px)"
# });
# }
# </script>
# <!-- GA -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-576564-4"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push( arguments ); }
# 	gtag( 'js', new Date() );
# 	gtag( 'config', 'UA-576564-4', { 'anonymize_ip': true } );
# 	gtag( 'config', 'UA-576564-21', { 'anonymize_ip': true } );
# </script>
# <!-- TL -->
# <script>
# 	( function() {
# 		if ( typeof window.fetch === 'function' ) {
# 			var w = window.location.href;
# 			if ( w.indexOf( '.php' ) == -1 ) {
# 				var data = 'action=wikiPageView&url=' + encodeURIComponent( w );
# 				window.fetch(
# 					"/stats/",
# 					{
# 						method: 'POST',
# 						headers: new Headers(
# 							{
# 								'Content-Type': 'application/x-www-form-urlencoded'
# 							}
# 						),
# 						body: data
# 					}
# 				);
# 			}
# 		}
# 	} )();
# </script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":1032});});</script></body></html>

# %%
soup.select('table')
# Out:
# [<table class="wikitable wikitable-striped sortable" style="margin-top:10px"><tbody><tr><th width="200">Player</th><th width="50">Team</th><th width="75">Agents</th><th width="50">Maps</th><th width="50">K</th><th width="50">D</th><th width="50">A</th><th width="50">KD</th><th width="50">KDA</th><th width="50">ACS/Map</th><th width="50">K/Map</th><th width="50">D/Map</th><th width="50">A/Map</th></tr><tr><td><span class="flag"><a href="/valorant/Category:Canada" title="Canada"><img alt="Canada" height="24" loading="lazy" src="/commons/images/7/72/Ca_hd.png" width="36"/></a></span> <a href="/valorant/TenZ" title="TenZ">TenZ</a></td><td style="text-align:center"><span class="team-template-team-icon" data-highlightingclass="Sentinels"><span class="team-template-image-icon"><a href="/valorant/Sentinels" title="Sentinels"><img alt="" height="50" loading="lazy" src="/commons/images/thumb/1/13/Sentinels_2020_allmode.png/50px-Sentinels_2020_allmode.png" srcset="/commons/images/thumb/1/13/Sentinels_2020_allmode.png/75px-Sentinels_2020_allmode.png 1.5x, /commons/images/thumb/1/13/Sentinels_2020_allmode.png/100px-Sentinels_2020_allmode.png 2x" width="50"/></a></span></span></td><td><a href="/valorant/Jett" title="Jett"><img alt="Jett" height="20" loading="lazy" src="/commons/images/thumb/f/ff/Jett_0.50_VALORANT_Icon.png/20px-Jett_0.50_VALORANT_Icon.png" srcset="/commons/images/thumb/f/ff/Jett_0.50_VALORANT_Icon.png/30px-Jett_0.50_VALORANT_Icon.png 1.5x, /commons/images/thumb/f/ff/Jett_0.50_VALORANT_Icon.png/40px-Jett_0.50_VALORANT_Icon.png 2x" width="20"/></a><a href="/valorant/Reyna" title="Reyna"><img alt="Reyna" height="20" loading="lazy" src="/commons/images/thumb/b/b4/Reyna_VALORANT_Icon.png/20px-Reyna_VALORANT_Icon.png" srcset="/commons/images/thumb/b/b4/Reyna_VALORANT_Icon.png/30px-Reyna_VALORANT_Icon.png 1.5x, /commons/images/thumb/b/b4/Reyna_VALORANT_Icon.png/40px-Reyna_VALORANT_Icon.png 2x" width="20"/></a><a href="/valorant/Raze" title="Raze"><img alt="Raze" height="20" loading="lazy" src="/commons/images/thumb/a/a4/Raze_0.50_VALORANT_Icon.png/20px-Raze_0.50_VALORANT_Icon.png" srcset="/commons/images/thumb/a/a4/Raze_0.50_VALORANT_Icon.png/30px-Raze_0.50_VALORANT_Icon.png 1.5x, /commons/images/thumb/a/a4/Raze_0.50_VALORANT_Icon.png/40px-Raze_0.50_VALORANT_Icon.png 2x" width="20"/></a></td><td style="text-align:center">9</td><td style="text-align:center">206</td><td style="text-align:center">139</td><td style="text-align:center">55</td><td style="text-align:center">1.48</td><td style="text-align:center">1.87</td><td style="text-align:center">289</td><td style="text-align:center">22.8</td><td style="text-align:center">15.4</td><td style="text-align:center">6.1</td></tr><tr><td><span class="flag"><a href="/valorant/Category:Belgium" title="Belgium"><img alt="Belgium" height="24" loading="lazy" src="/commons/images/0/00/Be_hd.png" width="36"/></a></span> <a href="/valorant/ScreaM" title="ScreaM">ScreaM</a></td><td style="text-align:center"><span class="team-template-team-icon" data-highlightingclass="Team Liquid"><span class="team-template-image-icon"><a href="/valorant/Team_Liquid" title="Team Liquid"><img alt="" height="50" loading="lazy" src="/commons/images/thumb/c/c9/Team_Liquid_2020_lightmode.png/44px-Team_Liquid_2020_lightmode.png" srcset="/commons/images/thumb/c/c9/Team_Liquid_2020_lightmode.png/66px-Team_Liquid_2020_lightmode.png 1.5x, /commons/images/thumb/c/c9/Team_Liquid_2020_lightmode.png/88px-Team_Liquid_2020_lightmode.png 2x" width="44"/></a></span></span></td><td><a href="/valorant/Sage" title="Sage"><img alt="Sage" height="20" loading="lazy" src="/commons/images/thumb/9/97/Sage_0.50_VALORANT_Icon.png/20px-Sage_0.50_VALORANT_Icon.png" srcset="/commons/images/thumb/9/97/Sage_0.50_VALORANT_Icon.png/30px-Sage_0.50_VALORANT_Icon.png 1.5x, /commons/images/thumb/9/97/Sage_0.50_VALORANT_Icon.png/40px-Sage_0.50_VALORANT_Icon.png 2x" width="20"/></a><a href="/valorant/Phoenix" title="Phoenix"><img alt="Phoenix" height="20" l ...

# %% [markdown]
# player stats

# %%
val_table = soup.find('table',attrs ={'class':'wikitable wikitable-striped sortable'})
val_table_data = val_table.tbody.find_all('tr')

# %%
headings=[]
for td in val_table_data[0].find_all('th'):
    headings.append(td.text)
print(headings)
# Out:
# ['Player', 'Team', 'Agents', 'Maps', 'K', 'D', 'A', 'KD', 'KDA', 'ACS/Map', 'K/Map', 'D/Map', 'A/Map']

# %%
import pandas as pd

# %%
data={'Player':[],'Country':[],'Team':[],'Agents':[]}
final_stat=[]
for i in range(1,len(val_table_data)):
    
    temp=[]
    stat_temp=[]
    
    for td in val_table_data[i].find_all('td'):
        stat_temp.append(td.text)
        
        for t in td.find_all('a'):
            
            temp.append(t.get('title'))
            
    data['Country'].append(temp[0])
    data['Player'].append(temp[1])
    data['Team'].append(temp[2])
    data['Agents'].append(temp[3:])
    final_stat.append(stat_temp)
    
stat=pd.DataFrame(final_stat)
stat.drop([0,1,2],axis=1,inplace=True)
stat.columns=['Maps', 'K', 'D', 'A', 'KD', 'KDA', 'ACS/Map', 'K/Map', 'D/Map', 'A/Map']
info=pd.DataFrame(data)
final_player_stats = pd.merge(info,stat,on=stat.index).drop('key_0',axis=1)

# %%
stat.head()
# Out:
#   Maps    K    D   A    KD   KDA ACS/Map K/Map D/Map A/Map
# 0    9  206  139  55  1.48  1.87     289  22.8  15.4   6.1
# 1    9  177  131  56  1.35  1.77     265  19.6  14.5   6.2
# 2    9  172  134  52  1.28  1.67     240  19.1  14.8   5.7
# 3    9  147  123  57  1.19  1.65     218  16.3  13.6   6.3
# 4    9  155  130  32  1.19  1.43     229  17.2  14.4   3.5

# %%
info.head()
# Out:
#     Player         Country         Team               Agents
# 0     TenZ          Canada    Sentinels  [Jett, Reyna, Raze]
# 1   ScreaM         Belgium  Team Liquid      [Sage, Phoenix]
# 2  ShahZaM   United States    Sentinels         [Sova, Jett]
# 3     L1NK  United Kingdom  Team Liquid    [Brimstone, Omen]
# 4   Jamppi         Finland  Team Liquid      [Jett, Killjoy]

# %%
final_player_stats
# Out:
#        Player         Country            Team                     Agents Maps  \
# 0        TenZ          Canada       Sentinels        [Jett, Reyna, Raze]    9
# 1      ScreaM         Belgium     Team Liquid            [Sage, Phoenix]    9
# 2     ShahZaM   United States       Sentinels               [Sova, Jett]    9
# 3        L1NK  United Kingdom     Team Liquid          [Brimstone, Omen]    9
# 4      Jamppi         Finland     Team Liquid            [Jett, Killjoy]    9
# 5       Lakia     South Korea   NUTURN Gaming               [Sova, Raze]   11
# 6        SicK   United States       Sentinels      [Phoenix, Raze, Sova]    9
# 7      Mistic  United Kingdom          Fnatic              [Viper, Skye]   16
# 8       Klaus       Argentina     KRÜ Esports            [Killjoy, Skye]    6
# 9        Sacy          Brazil    Team Vikings                     [Sova]    6
# 10   Patiphan        Thailand     X10 Esports        [Jett, Viper, Sage]    6
# 11      Derke         Finland          Fnatic               [Jett, Sova]   16
# 12      Effys          Canada        Version1               [Sova, Sage]   10
# 13     Magnum  Czech Republic          Fnatic    [Killjoy, Cypher, Skye]   16
# 14    Zellsis   United States        Version1         [Killjoy, Phoenix]   10
# 15      Penny          Canada        Version1                     [Jett]   10
# 16       Peri     South Korea   NUTURN Gaming              [Omen, Astra]   11
# 17       Neth           Japan   Crazy Raccoon                  [Killjoy]    4
# 18       Dapr   United States       Sentinels      [Cypher, Viper, Sage]    9
# 19       Doma         Croatia          Fnatic         [Sage, Omen, Raze]   16
# 20     SScary        Thailand     X10 Esports             [Astra, Viper]    6
# 21    Boaster  United Kingdom          Fnatic        [Astra, Sova, Skye]   16
# 22       Foxz        Thailand     X10 Esports               [Sova, Jett]    6
# 23    Soulcas  United Kingdom     Team Liquid               [Skye, Sova]    9
# 24     Gaabxx          Brazil  Sharks Esports        [Viper, Raze, Jett]    5
# 25     Mazino           Chile     KRÜ Esports              [Viper, Sage]    6
# 26     Prozin          Brazil  Sharks Esports            [Raze, Phoenix]    5
# 27     Zepher           Japan   Crazy Raccoon                     [Jett]    4
# 28    Suggest     South Korea   NUTURN Gaming       [Raze, Skye, Breach]   11
# 29      Allow     South Korea   NUTURN Gaming                     [Jett]   11
# 30      Zombs   United States       Sentinels             [Astra, Viper]    9
# 31     Vanity   United States        Version1              [Astra, Omen]   10
# 32    Sutecas          Brazil    Team Vikings              [Omen, Astra]    6
# 33    Kryptix  United Kingdom     Team Liquid           [Viper, Killjoy]    9
# 34    Saadhak       Argentina    Team Vikings          [Killjoy, Cypher]    6
# 35       Crws        Thailand     X10 Esports             [Skye, Breach]    6
# 36   Munchkin     South Korea   Crazy Raccoon      [Raze, Phoenix, Sage]    4
# 37     Delz1k           Chile     KRÜ Esports    [Sage, Omen, Brimstone]    6
# 38       NagZ           Chile     KRÜ Esports               [Jett, Sage]    6
# 39       Solo     South Korea   NUTURN Gaming  [Breach, Killjoy, Cypher]   11
# 40     Jammyz   United States        Version1           [Viper, Killjoy]   10
# 41  Sushiboys        Thailand     X10 Esports          [Killjoy, Cypher]    6
# 42        Bnj       Argentina     KRÜ Esports         [Sova, Raze, Skye]    6
# 43        Frz          Brazil    Team Vikings            [Jett, Phoenix]    6
# 44     Medusa     South Korea   Crazy Raccoon                     [Sova]    4
# 45       Rion           Japan   Crazy Raccoon       [Astra, Viper, Omen]    4
# 46     DeNaro          Brazil  Sharks Esports                     [Sova]    5
# 47     GtnziN          Brazil    Team Vikings               [Raze, Yoru]    6
# 48      Light          Brazil  Sharks Esports          [Omen, Brimstone]    5
# 49        Fra          Brazil  Sharks Esports      [Killjoy, Skye, Sage]    5
#
#       K    D    A    KD   KDA ACS/Map K/Map D/Map A/Map
# 0   206  139   55  1.48  1.87     289  22.8  15.4   6.1
# 1   177  131   56  1.35  1.77     265  19.6  14.5   6.2
# 2   172  134   52  1.28  1.67     240  19.1  14.8   5.7
# 3   147  123   57  1.19  1.65     218  16.3  13.6   6.3
# 4   155  130   32  1.19  1.43     229  17.2  14.4   3.5
# 5   174  146   62  1.19  1.61     231  15.8  13.2   5.6
# 6   147  126   61  1.16  1.65     218  16.3    14   6.7
# 7   240  206  120  1.16  1.74     191    15  12.8   7.5
# 8    87   75   25  1.15  1.49     234  14.5  12.5   4.1
# 9   100   89   30  1.12  1.46     206  16.6  14.8     5
# 10  109   98   38  1.11   1.5     235  18.1  16.3   6.3
# 11  298  270   85   1.1  1.41     260  18.6  16.8   5.3
# 12  161  146   69   1.1  1.57     186  16.1  14.6   6.9
# 13  270  246   83  1.09  1.43     215  16.8  15.3   5.1
# 14  184  168   61  1.09  1.45     230  18.4  16.8   6.1
# 15  185  173   40  1.06   1.3     227  18.5  17.3     4
# 16  151  142   43  1.06  1.36     184  13.7  12.9   3.9
# 17   63   61   15  1.03  1.27     203  15.7  15.2   3.7
# 18  127  123   73  1.03  1.62     184  14.1  13.6   8.1
# 19  247  241  120  1.02  1.52     205  15.4    15   7.5
# 20   88   87   35  1.01  1.41     157  14.6  14.5   5.8
# 21  241  241   81     1  1.33     190    15    15     5
# 22  100  100   33     1  1.33     206  16.6  16.6   5.5
# 23  124  124   64     1  1.51     188  13.7  13.7   7.1
# 24   65   66   17  0.98  1.24     199    13  13.2   3.4
# 25   78   80   46  0.97  1.55     213    13  13.3   7.6
# 26   70   75   15  0.93  1.13     237    14    15     3
# 27   62   67   10  0.92  1.07     202  15.5  16.7   2.5
# 28  146  158   36  0.92  1.15     186  13.2  14.3   3.2
# 29  150  163   30  0.92   1.1     198  13.6  14.8   2.7
# 30  121  133   67   0.9  1.41     170  13.4  14.7   7.4
# 31  158  174   63   0.9  1.27     197  15.8  17.4   6.3
# 32   88   98   26  0.89  1.16     174  14.6  16.3   4.3
# 33  104  117   54  0.88  1.35     161  11.5    13     6
# 34   81   92   26  0.88  1.16     166  13.5  15.3   4.3
# 35   81   93   34  0.87  1.23     171  13.5  15.5   5.6
# 36   62   72   27  0.86  1.23     210  15.5    18   6.7
# 37   62   73   22  0.84  1.15     157  10.3  12.1   3.6
# 38   67   81   13  0.82  0.98     169  11.1  13.5   2.1
# 39  137  167   65  0.82   1.2     188  12.4  15.1   5.9
# 40  136  169   56   0.8  1.13     176  13.6  16.9   5.6
# 41   74   92   28   0.8   1.1     161  12.3  15.3   4.6
# 42   60   79   38  0.75  1.24     173    10  13.1   6.3
# 43   75  100   24  0.75  0.99     139  12.5  16.6     4
# 44   51   70   23  0.72  1.05     178  12.7  17.5   5.7
# 45   46   67   16  0.68  0.92     148  11.5  16.7     4
# 46   45   69   24  0.65     1     161     9  13.8   4.8
# 47   60   96   28  0.62  0.91     141    10    16   4.6
# 48   35   67   22  0.52  0.85     125     7  13.4   4.4
# 49   35   69   17   0.5  0.75     122     7  13.8   3.4

# %%
final_player_stats.to_csv('player_stats.csv',index=False)

# %% [markdown]
# Map pick

# %%
map_table = soup.find("table",attrs={"class":"table table-bordered"})
map_table_values = map_table.tbody.find_all("tr")

# %%
final_data = []
for i in range(len(map_table_values)):
    temp=[]
    for td in map_table_values[i].find_all(['td','th']):
        temp.append(td.text)
    final_data.append(temp)
map_pick = pd.DataFrame(final_data)

# %%
map_pick.columns=map_pick.iloc[0]
map_pick.drop(0,inplace=True)
map_pick.set_index(keys='Map',inplace=True)

# %%
map_pick
# Out:
# 0      Total Day 1 Day 2 Day 3 Day 4 Day 5 Day 6 Day 7
# Map
# Ascent   16×    3×    3×    2×    3×    2×    2×    1×
# Bind      9×    1×    0×    2×    1×    2×    2×    1×
# Haven    15×    3×    3×    2×    2×    3×    1×    1×
# Icebox   10×    2×    2×    3×    1×    1×    0×    1×
# Split     6×    0×    1×    0×    2×    1×    1×    1×

# %%
for i in map_pick.columns:
    map_pick[i]=map_pick[i].apply(lambda x:int(x[:-1]))

# %%
map_pick
# Out:
# 0       Total  Day 1  Day 2  Day 3  Day 4  Day 5  Day 6  Day 7
# Map
# Ascent     16      3      3      2      3      2      2      1
# Bind        9      1      0      2      1      2      2      1
# Haven      15      3      3      2      2      3      1      1
# Icebox     10      2      2      3      1      1      0      1
# Split       6      0      1      0      2      1      1      1

# %%
map_pick.to_csv('map_pick_stats.csv')

# %% [markdown]
# Side pick

# %%
side_table = soup.find("table",attrs={"class":"wikitable wikitable-bordered wikitable-striped"})
side_table_values = side_table.tbody.find_all("tr")

# %%
final_data = []
for i in range(len(side_table_values)):
    temp=[]
    for td in side_table_values[i].find_all(['td','th']):
        temp.append(td.text)
    final_data.append(temp)
side_pick = pd.DataFrame(final_data)

# %%
side_pick
# Out:
#         0            1            2
# 0     Map     Atk Wins     Def Wins
# 1  Ascent   96 (42.5%)  130 (57.5%)
# 2    Bind   74 (57.4%)   55 (42.6%)
# 3   Haven  130 (55.3%)  105 (44.7%)
# 4  Icebox   99 (52.9%)   88 (47.1%)
# 5   Split   44 (45.4%)   53 (54.6%)

# %%
side_pick.columns=side_pick.iloc[0]

# %%
side_pick.drop(0,inplace=True)

# %%
side_pick.set_index(keys='Map',inplace=True)

# %%
side_pick
# Out:
# 0          Atk Wins     Def Wins
# Map
# Ascent   96 (42.5%)  130 (57.5%)
# Bind     74 (57.4%)   55 (42.6%)
# Haven   130 (55.3%)  105 (44.7%)
# Icebox   99 (52.9%)   88 (47.1%)
# Split    44 (45.4%)   53 (54.6%)

# %%
side_pick['Atk Wins']=side_pick['Atk Wins'].apply(lambda x:int(x.split()[0]))
side_pick['Def Wins']=side_pick['Def Wins'].apply(lambda x:int(x.split()[0]))

# %%
side_pick
# Out:
# 0       Atk Wins  Def Wins
# Map
# Ascent        96       130
# Bind          74        55
# Haven        130       105
# Icebox        99        88
# Split         44        53

# %%
side_pick.to_csv('side_pick_stats.csv')

# %% [markdown]
# Map banned

# %%
banned_table = soup.find("table",attrs={"class":"table table-bordered"})
banned_table = banned_table.find_next("table").find_next("table")
banned_table_values = banned_table.tbody.find_all("tr")

# %%
final_table=[]
for i in range(len(banned_table_values)):
    temp=[]
    for td in banned_table_values[i].find_all(['td','th']):
        temp.append(td.text)
    final_table.append(temp)
banned_final = pd.DataFrame(final_table)

# %%
banned_final.columns = banned_final.iloc[0]

# %%
banned_final.drop(0,inplace=True)

# %%
banned_final.set_index('Map',inplace=True)

# %%
for i in map_pick.columns:
    banned_final[i]=banned_final[i].apply(lambda x:int(x[:-1]))

# %%
banned_final
# Out:
# 0       Total  Day 1  Day 2  Day 3  Day 4  Day 5  Day 6  Day 7
# Map
# Ascent      2      0      0      1      0      1      0      0
# Bind        9      2      3      1      2      1      0      0
# Haven       3      0      0      1      1      0      1      0
# Icebox      8      1      1      0      2      2      2      0
# Split      12      3      2      3      1      2      1      0

# %%
banned_final.to_csv('banned_maps_stats.csv')
